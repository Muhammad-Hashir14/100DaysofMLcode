# %%
import numpy as np
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mtcars = pd.read_csv('https://raw.githubusercontent.com/sap0408/mtcars/master/mtcars.csv')

# %%
mtcars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
graph = sns.barplot(mtcars['cyl'],mtcars['mpg'])
plt.show()
# Out:
# C:\Users\hashi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
graph = sns.barplot(x = 'cyl',y = 'mpg',data= mtcars)

# %%
graph = sns.barplot(x = 'cyl', y = 'mpg', data = mtcars, color = 'purple')

# %%
graph = sns.barplot(x = 'am', y = 'mpg', data = mtcars, palette = 'Set1')

# %%
graph = sns.barplot(x = 'am', y= 'mpg', data = mtcars,palette = 'rocket')

# %%
graph = sns.countplot(x = 'cyl', data = mtcars)

# %%
graph = sns.countplot(x = 'carb', data = mtcars, palette = 'Set2')

# %%
graph = sns.countplot(y = 'gear',data = mtcars, palette = 'Set1')

# %%
graph = sns.countplot(x = 'gear', hue = 'cyl', data = mtcars, palette = 'Set3')

# %%
graph = sns.distplot(mtcars['mpg'], bins = 10, color = 'g')
# Out:
# C:\Users\hashi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.heatmap(mtcars.corr() ,linewidths = 0.5)
# Out:
# <AxesSubplot:>

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.scatterplot(x = 'sepal_length',y='petal_length',data = iris, palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = 'sepal_length', y= 'petal_length', data = iris, hue = 'species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = 'sepal_length', y= 'petal_length', data = iris, hue = 'species' , size = 'species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue = 'species', palette = 'Set1')

# %%
sns.lmplot(x = 'sepal_length', y = 'petal_length', data = iris)

# %%
sns.lmplot(x = 'sepal_length', y = 'petal_length', hue = 'species',data = iris, markers = ['o','^','*'])

# %%
sns.boxplot(x = 'species',y = 'petal_width', data = iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>
