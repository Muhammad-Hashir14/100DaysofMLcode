# %%
import pandas as pd

# %%
data = pd.read_csv('https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/e38afe62e088394d61ed30884dd50a6826eee0a8/employees.csv', index_col='EMPLOYEE_ID')

# %%
data1 = pd.read_csv('https://raw.githubusercontent.com/jichaojoyce/data-science-project-1/master/survey-results-schema.csv')

# %%
data
# Out:
#               FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# EMPLOYEE_ID
# 198               Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 199              Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 200             Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 201              Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 202                  Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 203                Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 204              Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 205              Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 206              William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 100               Steven         King     SKING  515.123.4567  17-JUN-03
# 101                Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 102                  Lex      De Haan   LDEHAAN  515.123.4569  13-JAN-01
# 103            Alexander       Hunold   AHUNOLD  590.423.4567  03-JAN-06
# 104                Bruce        Ernst    BERNST  590.423.4568  21-MAY-07
# 105                David       Austin   DAUSTIN  590.423.4569  25-JUN-05
# 106                Valli    Pataballa  VPATABAL  590.423.4560  05-FEB-06
# 107                Diana      Lorentz  DLORENTZ  590.423.5567  07-FEB-07
# 108                Nancy    Greenberg  NGREENBE  515.124.4569  17-AUG-02
# 109               Daniel       Faviet   DFAVIET  515.124.4169  16-AUG-02
# 110                 John         Chen     JCHEN  515.124.4269  28-SEP-05
# 111               Ismael      Sciarra  ISCIARRA  515.124.4369  30-SEP-05
# 112          Jose Manuel        Urman   JMURMAN  515.124.4469  07-MAR-06
# 113                 Luis         Popp     LPOPP  515.124.4567  07-DEC-07
# 114                  Den     Raphaely  DRAPHEAL  515.127.4561  07-DEC-02
# 115            Alexander         Khoo     AKHOO  515.127.4562  18-MAY-03
# 116               Shelli        Baida    SBAIDA  515.127.4563  24-DEC-05
# 117                Sigal       Tobias   STOBIAS  515.127.4564  24-JUL-05
# 118                  Guy       Himuro   GHIMURO  515.127.4565  15-NOV-06
# 119                Karen   Colmenares  KCOLMENA  515.127.4566  10-AUG-07
# 120              Matthew        Weiss    MWEISS  650.123.1234  18-JUL-04
# 121                 Adam        Fripp    AFRIPP  650.123.2234  10-APR-05
# 122                Payam     Kaufling  PKAUFLIN  650.123.3234  01-MAY-03
# 123               Shanta      Vollman  SVOLLMAN  650.123.4234  10-OCT-05
# 124                Kevin      Mourgos  KMOURGOS  650.123.5234  16-NOV-07
# 125                Julia        Nayer    JNAYER  650.124.1214  16-JUL-05
# 126                Irene  Mikkilineni  IMIKKILI  650.124.1224  28-SEP-06
# 127                James       Landry   JLANDRY  650.124.1334  14-JAN-07
# 128               Steven       Markle   SMARKLE  650.124.1434  08-MAR-08
# 129                Laura       Bissot   LBISSOT  650.124.5234  20-AUG-05
# 130                Mozhe     Atkinson  MATKINSO  650.124.6234  30-OCT-05
# 131                James       Marlow   JAMRLOW  650.124.7234  16-FEB-05
# 132                   TJ        Olson   TJOLSON  650.124.8234  10-APR-07
# 133                Jason       Mallin   JMALLIN  650.127.1934  14-JUN-04
# 134              Michael       Rogers   MROGERS  650.127.1834  26-AUG-06
# 135                   Ki          Gee      KGEE  650.127.1734  12-DEC-07
# 136                Hazel   Philtanker  HPHILTAN  650.127.1634  06-FEB-08
# 137               Renske       Ladwig   RLADWIG  650.121.1234  14-JUL-03
# 138              Stephen       Stiles   SSTILES  650.121.2034  26-OCT-05
# 139                 John          Seo      JSEO  650.121.2019  12-FEB-06
# 140               Joshua        Patel    JPATEL  650.121.1834  06-APR-06
#
#                  JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# EMPLOYEE_ID
# 198            SH_CLERK    2600             -         124             50
# 199            SH_CLERK    2600             -         124             50
# 200             AD_ASST    4400             -         101             10
# 201              MK_MAN   13000             -         100             20
# 202              MK_REP    6000             -         201             20
# 203              HR_REP    6500             -         101             40
# 204              PR_REP   10000             -         101             70
# 205              AC_MGR   12008             -         101            110
# 206          AC_ACCOUNT    8300             -         205            110
# 100             AD_PRES   24000             -          -              90
# 101               AD_VP   17000             -         100             90
# 102               AD_VP   17000             -         100             90
# 103             IT_PROG    9000             -         102             60
# 104             IT_PROG    6000             -         103             60
# 105             IT_PROG    4800             -         103             60
# 106             IT_PROG    4800             -         103             60
# 107             IT_PROG    4200             -         103             60
# 108              FI_MGR   12008             -         101            100
# 109          FI_ACCOUNT    9000             -         108            100
# 110          FI_ACCOUNT    8200             -         108            100
# 111          FI_ACCOUNT    7700             -         108            100
# 112          FI_ACCOUNT    7800             -         108            100
# 113          FI_ACCOUNT    6900             -         108            100
# 114              PU_MAN   11000             -         100             30
# 115            PU_CLERK    3100             -         114             30
# 116            PU_CLERK    2900             -         114             30
# 117            PU_CLERK    2800             -         114             30
# 118            PU_CLERK    2600             -         114             30
# 119            PU_CLERK    2500             -         114             30
# 120              ST_MAN    8000             -         100             50
# 121              ST_MAN    8200             -         100             50
# 122              ST_MAN    7900             -         100             50
# 123              ST_MAN    6500             -         100             50
# 124              ST_MAN    5800             -         100             50
# 125            ST_CLERK    3200             -         120             50
# 126            ST_CLERK    2700             -         120             50
# 127            ST_CLERK    2400             -         120             50
# 128            ST_CLERK    2200             -         120             50
# 129            ST_CLERK    3300             -         121             50
# 130            ST_CLERK    2800             -         121             50
# 131            ST_CLERK    2500             -         121             50
# 132            ST_CLERK    2100             -         121             50
# 133            ST_CLERK    3300             -         122             50
# 134            ST_CLERK    2900             -         122             50
# 135            ST_CLERK    2400             -         122             50
# 136            ST_CLERK    2200             -         122             50
# 137            ST_CLERK    3600             -         123             50
# 138            ST_CLERK    3200             -         123             50
# 139            ST_CLERK    2700             -         123             50
# 140            ST_CLERK    2500             -         123             50

# %%
data.agg({
    'SALARY':['mean','median','max','min']
})
# Out:
#           SALARY
# mean     6182.32
# median   4600.00
# max     24000.00
# min      2100.00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 198 to 140
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   FIRST_NAME      50 non-null     object
#  1   LAST_NAME       50 non-null     object
#  2   EMAIL           50 non-null     object
#  3   PHONE_NUMBER    50 non-null     object
#  4   HIRE_DATE       50 non-null     object
#  5   JOB_ID          50 non-null     object
#  6   SALARY          50 non-null     int64
#  7   COMMISSION_PCT  50 non-null     object
#  8   MANAGER_ID      50 non-null     object
#  9   DEPARTMENT_ID   50 non-null     int64
# dtypes: int64(2), object(8)
# memory usage: 4.3+ KB

# %%
data.describe()
# Out:
#              SALARY  DEPARTMENT_ID
# count     50.000000       50.00000
# mean    6182.320000       57.60000
# std     4586.181772       25.11687
# min     2100.000000       10.00000
# 25%     2725.000000       50.00000
# 50%     4600.000000       50.00000
# 75%     8150.000000       60.00000
# max    24000.000000      110.00000
